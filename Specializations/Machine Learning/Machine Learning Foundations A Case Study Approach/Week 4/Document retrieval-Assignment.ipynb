# %% [markdown]
# # Document retrieval from wikipedia data
#
# # Fire up GraphLab Create

# %%
import graphlab

# %% [markdown]
# # Load some text data - from wikipedia, pages on people

# %%
people = graphlab.SFrame('people_wiki.gl/')
# Out:
# [INFO] This non-commercial license of GraphLab Create is assigned to thomasv1000@hotmail.fr and will expire on October 12, 2016. For commercial licensing options, visit https://dato.com/buy/.
#
# [INFO] Start server at: ipc:///tmp/graphlab_server-9582 - Server binary: /Users/tjaskula/.graphlab/anaconda/lib/python2.7/site-packages/graphlab/unity_server - Server log: /tmp/graphlab_server_1446655413.log
# [INFO] GraphLab Server Version: 1.6.1

# %% [markdown]
# Data contains:  link to wikipedia article, name of person, text of article.

# %%
people.head()
# Out:
# Columns:
# 	URI	str
# 	name	str
# 	text	str
#
# Rows: 10
#
# Data:
# +-------------------------------+---------------------+
# |              URI              |         name        |
# +-------------------------------+---------------------+
# | <http://dbpedia.org/resour... |    Digby Morrell    |
# | <http://dbpedia.org/resour... |    Alfred J. Lewy   |
# | <http://dbpedia.org/resour... |    Harpdog Brown    |
# | <http://dbpedia.org/resour... | Franz Rottensteiner |
# | <http://dbpedia.org/resour... |        G-Enka       |
# | <http://dbpedia.org/resour... |    Sam Henderson    |
# | <http://dbpedia.org/resour... |    Aaron LaCrate    |
# | <http://dbpedia.org/resour... |   Trevor Ferguson   |
# | <http://dbpedia.org/resour... |     Grant Nelson    |
# | <http://dbpedia.org/resour... |     Cathy Caruth    |
# +-------------------------------+---------------------+
# +-------------------------------+
# |              text             |
# +-------------------------------+
# ...

# %%
len(people)
# Out:
# 59071

# %% [markdown]
# # Explore the dataset and checkout the text it contains
#
# ## Exploring the entry for president Obama

# %%
obama = people[people['name'] == 'Barack Obama']

# %%
obama
# Out:
# Columns:
# 	URI	str
# 	name	str
# 	text	str
#
# Rows: Unknown
#
# Data:
# +-------------------------------+--------------+-------------------------------+
# |              URI              |     name     |              text             |
# +-------------------------------+--------------+-------------------------------+
# | <http://dbpedia.org/resour... | Barack Obama | barack hussein obama ii br... |
# +-------------------------------+--------------+-------------------------------+
# [? rows x 3 columns]
# Note: Only the head of the SFrame is printed. This SFrame is lazily evaluated.
# You can use len(sf) to force materialization.

# %%
obama['text']
# Out:
# dtype: str
# Rows: ?
# ...

# %% [markdown]
# ## Exploring the entry for actor George Clooney

# %%
clooney = people[people['name'] == 'George Clooney']
clooney['text']
# Out:
# dtype: str
# Rows: ?
# ...

# %% [markdown]
# # Get the word counts for Obama article

# %%
obama['word_count'] = graphlab.text_analytics.count_words(obama['text'])

# %%
print obama['word_count']
# Out:
# [{'operations': 1, 'represent': 1, 'office': 2, 'unemployment': 1, 'is': 2, 'doddfrank': 1, 'over': 1, 'unconstitutional': 1, 'domestic': 2, 'named': 1, 'ending': 1, 'ended': 1, 'proposition': 1, 'seats': 1, 'graduate': 1, 'worked': 1, 'before': 1, 'death': 1, '20': 2, 'taxpayer': 1, 'inaugurated': 1, 'obamacare': 1, 'civil': 1, 'mccain': 1, 'to': 14, '4': 1, 'policy': 2, '8': 1, 'has': 4, '2011': 3, '2010': 2, '2013': 1, '2012': 1, 'bin': 1, 'then': 1, 'his': 11, 'march': 1, 'gains': 1, 'cuba': 1, 'californias': 1, '1992': 1, 'new': 1, 'not': 1, 'during': 2, 'years': 1, 'continued': 1, 'presidential': 2, 'husen': 1, 'osama': 1, 'term': 3, 'equality': 1, 'prize': 1, 'lost': 1, 'stimulus': 1, 'january': 3, 'university': 2, 'rights': 1, 'gun': 1, 'republican': 2, 'rodham': 1, 'troop': 1, 'withdrawal': 1, 'involvement': 3, 'response': 3, 'where': 1, 'referred': 1, 'affordable': 1, 'attorney': 1, 'school': 3, 'senate': 3, 'house': 2, 'national': 2, 'creation': 1, 'related': 1, 'hawaii': 
# ...

# %% [markdown]
# ## Sort the word counts for the Obama article

# %% [markdown]
# ### Turning dictonary of word counts into a table

# %%
obama_word_count_table = obama[['word_count']].stack('word_count', new_column_name = ['word','count'])

# %% [markdown]
# ### Sorting the word counts to show most common words at the top

# %%
obama_word_count_table.head()
# Out:
# Columns:
# 	word	str
# 	count	int
#
# Rows: 10
#
# Data:
# +------------+-------+
# |    word    | count |
# +------------+-------+
# |    cuba    |   1   |
# | relations  |   1   |
# |   sought   |   1   |
# |   combat   |   1   |
# |   ending   |   1   |
# | withdrawal |   1   |
# |   state    |   1   |
# |  islamic   |   1   |
# |     by     |   1   |
# |   gains    |   1   |
# +------------+-------+
# [10 rows x 2 columns]

# %%
obama_word_count_table.sort('count',ascending=False)
# Out:
# Columns:
# 	word	str
# 	count	int
#
# Rows: 273
#
# Data:
# +-------+-------+
# |  word | count |
# +-------+-------+
# |  the  |   40  |
# |   in  |   30  |
# |  and  |   21  |
# |   of  |   18  |
# |   to  |   14  |
# |  his  |   11  |
# | obama |   9   |
# |  act  |   8   |
# |   he  |   7   |
# |   a   |   7   |
# +-------+-------+
# [273 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# Most common words include uninformative words like "the", "in", "and",...

# %% [markdown]
# # Compute TF-IDF for the corpus
#
# To give more weight to informative words, we weigh them by their TF-IDF scores.

# %%
people['word_count'] = graphlab.text_analytics.count_words(people['text'])
people.head()
# Out:
# Columns:
# 	URI	str
# 	name	str
# 	text	str
# 	word_count	dict
# 	tfidf	dict
#
# Rows: 10
#
# Data:
# +-------------------------------+---------------------+
# |              URI              |         name        |
# +-------------------------------+---------------------+
# | <http://dbpedia.org/resour... |    Digby Morrell    |
# | <http://dbpedia.org/resour... |    Alfred J. Lewy   |
# | <http://dbpedia.org/resour... |    Harpdog Brown    |
# | <http://dbpedia.org/resour... | Franz Rottensteiner |
# | <http://dbpedia.org/resour... |        G-Enka       |
# | <http://dbpedia.org/resour... |    Sam Henderson    |
# | <http://dbpedia.org/resour... |    Aaron LaCrate    |
# | <http://dbpedia.org/resour... |   Trevor Ferguson   |
# | <http://dbpedia.org/resour... |     Grant Nelson    |
# | <http://dbpedia.org/resour... |     Cathy Caruth    |
# +-------------------------------+---------------------+
# +-------------------------------+-------------------------------+
# ...

# %%
tfidf = graphlab.text_analytics.tf_idf(people['word_count'])
tfidf
# Out:
# Columns:
# 	docs	dict
#
# Rows: 59071
#
# Data:
# +-------------------------------+
# |              docs             |
# +-------------------------------+
# | {'selection': 3.8365785530... |
# | {'precise': 6.443200606955... |
# | {'just': 2.700729968710864... |
# | {'all': 1.6431112434912472... |
# | {'they': 1.899340117819389... |
# | {'currently': 1.6370889691... |
# | {'exclusive': 10.455187230... |
# | {'taxi': 6.052021456094502... |
# | {'houston': 3.935505942157... |
# | {'phenomenon': 5.750053426... |
# +-------------------------------+
# [59071 rows x 1 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
people['tfidf'] = tfidf['docs']

# %% [markdown]
# ## Examine the TF-IDF for the Obama article

# %%
obama = people[people['name'] == 'Barack Obama']

# %%
obama[['tfidf']].stack('tfidf',new_column_name=['word','tfidf']).sort('tfidf',ascending=False)
# Out:
# Columns:
# 	word	str
# 	tfidf	float
#
# Rows: 273
#
# Data:
# +-------------+---------------+
# |     word    |     tfidf     |
# +-------------+---------------+
# |    obama    | 43.2956530721 |
# |     act     |  27.678222623 |
# |     iraq    |  17.747378588 |
# |   control   | 14.8870608452 |
# |     law     | 14.7229357618 |
# |   ordered   | 14.5333739509 |
# |   military  | 13.1159327785 |
# | involvement | 12.7843852412 |
# |   response  | 12.7843852412 |
# |  democratic | 12.4106886973 |
# +-------------+---------------+
# [273 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# Words with highest TF-IDF are much more informative.

# %% [markdown]
# # Manually compute distances between a few people
#
# Let's manually compare the distances between the articles for a few famous people.

# %%
clinton = people[people['name'] == 'Bill Clinton']

# %%
beckham = people[people['name'] == 'David Beckham']

# %% [markdown]
# ## Is Obama closer to Clinton than to Beckham?
#
# We will use cosine distance, which is given by
#
# (1-cosine_similarity)
#
# and find that the article about president Obama is closer to the one about former president Clinton than that of footballer David Beckham.

# %%
graphlab.distances.cosine(obama['tfidf'][0],clinton['tfidf'][0])
# Out:
# 0.8339854936884277

# %%
graphlab.distances.cosine(obama['tfidf'][0],beckham['tfidf'][0])
# Out:
# 0.9791305844747478

# %% [markdown]
# # Build a nearest neighbor model for document retrieval
#
# We now create a nearest-neighbors model and apply it to document retrieval.

# %%
knn_model = graphlab.nearest_neighbors.create(people,features=['tfidf'],label='name')
# Out:
# PROGRESS: Starting brute force nearest neighbors model training.

# %% [markdown]
# # Applying the nearest-neighbors model for retrieval

# %% [markdown]
# ## Who is closest to Obama?

# %%
knn_model.query(obama)
# Out:
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.00169288  | 16.295ms     |
# PROGRESS: | Done         |         | 100         | 217.608ms    |
# PROGRESS: +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-----------------+----------------+------+
# | query_label | reference_label |    distance    | rank |
# +-------------+-----------------+----------------+------+
# |      0      |   Barack Obama  |      0.0       |  1   |
# |      0      |    Joe Biden    | 0.794117647059 |  2   |
# |      0      |  Joe Lieberman  | 0.794685990338 |  3   |
# |      0      |   Kelly Ayotte  | 0.811989100817 |  4   |
# ...

# %% [markdown]
# As we can see, president Obama's article is closest to the one about his vice-president Biden, and those of other politicians.

# %% [markdown]
# ## Other examples of document retrieval

# %%
swift = people[people['name'] == 'Taylor Swift']

# %%
knn_model.query(swift)
# Out:
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.00169288  | 14.626ms     |
# PROGRESS: | Done         |         | 100         | 210.687ms    |
# PROGRESS: +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+------------------+----------------+------+
# | query_label | reference_label  |    distance    | rank |
# +-------------+------------------+----------------+------+
# |      0      |   Taylor Swift   |      0.0       |  1   |
# |      0      | Carrie Underwood | 0.76231884058  |  2   |
# |      0      |   Alicia Keys    | 0.764705882353 |  3   |
# |      0      |  Jordin Sparks   | 0.769633507853 |  4   |
# ...

# %%
jolie = people[people['name'] == 'Angelina Jolie']

# %%
knn_model.query(jolie)
# Out:
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.00169288  | 12.816ms     |
# PROGRESS: | Done         |         | 100         | 204.868ms    |
# PROGRESS: +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+--------------------+----------------+------+
# | query_label |  reference_label   |    distance    | rank |
# +-------------+--------------------+----------------+------+
# |      0      |   Angelina Jolie   |      0.0       |  1   |
# |      0      |     Brad Pitt      | 0.784023668639 |  2   |
# |      0      |   Julianne Moore   | 0.795857988166 |  3   |
# |      0      | Billy Bob Thornton | 0.803069053708 |  4   |
# ...

# %%
arnold = people[people['name'] == 'Arnold Schwarzenegger']

# %%
knn_model.query(arnold)
# Out:
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.00169288  | 13.538ms     |
# PROGRESS: | Done         |         | 100         | 227.99ms     |
# PROGRESS: +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-----------------------+----------------+------+
# | query_label |    reference_label    |    distance    | rank |
# +-------------+-----------------------+----------------+------+
# |      0      | Arnold Schwarzenegger |      0.0       |  1   |
# |      0      |     Jesse Ventura     | 0.818918918919 |  2   |
# |      0      |     John Kitzhaber    | 0.824615384615 |  3   |
# ...

# %% [markdown]
# # Assignment
# ## Retrieving Wikipedia articles
#
# ### 1. Top word count words for Elton John

# %%
elton = people[people['name'] == 'Elton John']

# %%
elton['word_count'] = graphlab.text_analytics.count_words(elton['text'])

# %%
print elton['word_count']
# Out:
# [{'all': 1, 'least': 1, 'producer': 1, 'heavily': 1, 'inducted': 1, 'john': 7, 'over': 2, 'named': 1, 'making': 1, 'years': 1, 'four': 1, 'openly': 1, 'including': 1, 'highestprofile': 1, 'its': 2, 'impact': 1, '1': 2, '27': 1, '21': 2, 'wed': 1, 'datein': 1, 'royal': 1, '1947': 1, 'abbey': 1, 'winning': 1, 'late': 1, 'to': 4, 'taupin': 1, 'born': 1, '2014': 1, 'as': 2, 'has': 9, '2013': 1, 'his': 4, 'march': 1, '10': 1, 'songwriter': 2, 'solo': 1, 'continues': 1, 'records': 1, 'five': 1, 'occasional': 1, 'they': 1, 'inception': 1, 'world': 1, 'one': 3, 'hall': 2, 'bestselling': 2, 'fivedecade': 1, 'knighthood': 1, '58': 1, 'artist': 1, 'roll': 2, 'inductee': 1, 'list': 1, 'events': 1, 'hercules': 1, 'announced': 1, 'rock': 2, 'alltime': 1, 'brit': 1, 'bernie': 1, 'england': 1, 'concert': 1, 'be': 1, 'diana': 1, 'globe': 1, 'artists': 2, 'him': 3, 'culture': 1, 'year': 1, 'billboard': 4, 'aids': 2, 'empire': 1, 'honors': 1, 'composers': 1, 'established': 1, 'elton': 3, 'for': 5, 'rec
# ...

# %%
elton_word_count_table = elton[['word_count']].stack('word_count', new_column_name = ['word','count'])

# %%
elton_word_count_table.head()
# Out:
# Columns:
# 	word	str
# 	count	int
#
# Rows: 10
#
# Data:
# +----------+-------+
# |   word   | count |
# +----------+-------+
# |  social  |   1   |
# | champion |   1   |
# |    be    |   1   |
# |   2014   |   1   |
# |  legal   |   1   |
# |  became  |   1   |
# |   2005   |   1   |
# | december |   2   |
# |    21    |   2   |
# | furnish  |   2   |
# +----------+-------+
# [10 rows x 2 columns]

# %%
elton_word_count_table.sort('count',ascending=False)
# Out:
# Columns:
# 	word	str
# 	count	int
#
# Rows: 255
#
# Data:
# +-------+-------+
# |  word | count |
# +-------+-------+
# |  the  |   27  |
# |   in  |   18  |
# |  and  |   15  |
# |   of  |   13  |
# |   a   |   10  |
# |  has  |   9   |
# |  john |   7   |
# |   he  |   7   |
# |   on  |   6   |
# | award |   5   |
# +-------+-------+
# [255 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# ### 2. Top TF-IDF words for Elton John

# %%
elton = people[people['name'] == 'Elton John']

# %%
elton[['tfidf']].stack('tfidf',new_column_name=['word','tfidf']).sort('tfidf',ascending=False)
# Out:
# Columns:
# 	word	str
# 	tfidf	float
#
# Rows: 255
#
# Data:
# +---------------+---------------+
# |      word     |     tfidf     |
# +---------------+---------------+
# |    furnish    |  18.38947184  |
# |     elton     |  17.48232027  |
# |   billboard   | 17.3036809575 |
# |      john     | 13.9393127924 |
# |  songwriters  |  11.250406447 |
# | tonightcandle | 10.9864953892 |
# |  overallelton | 10.9864953892 |
# |    19702000   | 10.2933482087 |
# |   fivedecade  | 10.2933482087 |
# |      aids     |  10.262846934 |
# +---------------+---------------+
# [255 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# ### 3. The cosine distance between 'Elton John's and 'Victoria Beckham's articles (represented with TF-IDF) falls within which range?

# %%
viki = people[people['name'] == 'Victoria Beckham']

# %%
graphlab.distances.cosine(elton['tfidf'][0],viki['tfidf'][0])
# Out:
# 0.9567006376655429

# %% [markdown]
# ### 4. The cosine distance between 'Elton John's and 'Paul McCartney's articles (represented with TF-IDF) falls within which range?

# %%
paul = people[people['name'] == 'Paul McCartney']

# %%
graphlab.distances.cosine(elton['tfidf'][0],paul['tfidf'][0])
# Out:
# 0.8250310029221779

# %% [markdown]
# ### 5. Who is closer to 'Elton John', 'Victoria Beckham' or 'Paul McCartney'?

# %% [markdown]
# Paul McCartney

# %% [markdown]
# ### 6. Who is the nearest neighbor to 'Elton John' using raw word counts?

# %%
knn_model_raw = graphlab.nearest_neighbors.create(people,features=['word_count'],label='name')
# Out:
# PROGRESS: Starting brute force nearest neighbors model training.

# %%
knn_model_raw.query(elton)
# Out:
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.00169288  | 15.742ms     |
# PROGRESS: | Done         |         | 100         | 194.767ms    |
# PROGRESS: +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-----------------+----------------+------+
# | query_label | reference_label |    distance    | rank |
# +-------------+-----------------+----------------+------+
# |      0      |    Elton John   |      0.0       |  1   |
# |      0      |   Phil Collins  | 0.76399026764  |  2   |
# |      0      |   Rod Stewart   | 0.773333333333 |  3   |
# |      0      |   Annie Lennox  | 0.776623376623 |  4   |
# ...

# %%
joel = people[people['name'] == 'Billy Joel']
richard = people[people['name'] == 'Cliff Richard']
daltrey = people[people['name'] == 'Roger Daltrey']
bush = people[people['name'] == 'George Bush']

# %%
print graphlab.distances.cosine(elton['word_count'][0],joel['word_count'][0])
print graphlab.distances.cosine(elton['word_count'][0],richard['word_count'][0])
print graphlab.distances.cosine(elton['word_count'][0],daltrey['word_count'][0])
# Out:
# 0.222217647818
# 0.16142415259
# 0.177554184666

# %% [markdown]
# Cliff Richard

# %% [markdown]
# ### 7. Who is the nearest neighbor to 'Elton John' using TF-IDF?

# %%
knn_model.query(elton)
# Out:
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.00169288  | 15.244ms     |
# PROGRESS: | Done         |         | 100         | 233.441ms    |
# PROGRESS: +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-----------------+----------------+------+
# | query_label | reference_label |    distance    | rank |
# +-------------+-----------------+----------------+------+
# |      0      |    Elton John   |      0.0       |  1   |
# |      0      |   Phil Collins  | 0.76399026764  |  2   |
# |      0      |   Rod Stewart   | 0.773333333333 |  3   |
# |      0      |   Annie Lennox  | 0.776623376623 |  4   |
# ...

# %% [markdown]
# Rod Stewart

# %% [markdown]
# ### 8. Who is the nearest neighbor to 'Victoria Beckham' using raw word counts?

# %%
sdb = people[people['name'] == 'Stephen Dow Beckham']
malloy = people[people['name'] == 'Louis Molloy']
corri = people[people['name'] == 'Adrienne Corri']
fitzgerald = people[people['name'] == 'Mary Fitzgerald (artist)']

# %%
print graphlab.distances.cosine(viki['word_count'][0],sdb['word_count'][0])
print graphlab.distances.cosine(viki['word_count'][0],malloy['word_count'][0])
print graphlab.distances.cosine(viki['word_count'][0],corri['word_count'][0])
print graphlab.distances.cosine(viki['word_count'][0],fitzgerald['word_count'][0])
# Out:
# 0.31219127606
# 0.310507512959
# 0.214509782788
# 0.207307036115

# %% [markdown]
# Mary Fitzgerald (artist)

# %% [markdown]
# ### 9. Who is the nearest neighbor to 'Victoria Beckham' using TF-IDF?

# %%
knn_model.query(viki)
# Out:
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.00169288  | 19.92ms      |
# PROGRESS: | Done         |         | 100         | 245.812ms    |
# PROGRESS: +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+------------------+----------------+------+
# | query_label | reference_label  |    distance    | rank |
# +-------------+------------------+----------------+------+
# |      0      | Victoria Beckham |      0.0       |  1   |
# |      0      |   Cheryl Cole    | 0.800586510264 |  2   |
# |      0      |    Heidi Klum    | 0.810344827586 |  3   |
# |      0      |   Simon Fuller   | 0.822742474916 |  4   |
# ...
